# %% [markdown]
# Welcome to the PROT_CLUST tool

# %% [markdown]
# 🧬 PROT_CLUST: Protein-Protein Interaction Clustering Pipeline
# This notebook manages the full workflow for the PROT_CLUST project. It handles environment setup, data import, preprocessing, clustering (Louvain & MCL), and result analysis.

# %% [markdown]
# 1. Project Environment Setup
#
# This section ensures all necessary directories (_raw, data, output, etc.) exist and that dependencies are met.

# %%
import os
import sys
import subprocess
import platform
from pathlib import Path

# --- Configuration for Directory Structure ---
PROJECT_STRUCTURE = [
    "_raw",
    "data",
    "data/output",
    "features",
    "features/plotting",
    ".venv"
]

def create_structure():
    """Creates the necessary folder structure if it doesn't exist."""
    print(f"📁 Checking directory structure...")
    root_dir = Path.cwd() # Current working directory (assuming notebook is in root)
    
    for folder in PROJECT_STRUCTURE:
        folder_path = root_dir / folder
        if not folder_path.exists():
            print(f"   + Creating missing directory: {folder}/")
            os.makedirs(folder_path, exist_ok=True)
        else:
            pass # Directory exists, stay silent to keep output clean

def check_data_files():
    """Checks if raw data files (ignored by git) are present."""
    # Adjust filenames here if they change
    required_files = [
        Path("_raw/9606.protein.info.v12.0.txt"),
        Path("_raw/9606.protein.links.v12.0.min400.txt")
    ]
    
    missing_data = [f for f in required_files if not f.exists()]
    
    if missing_data:
        print("\n⚠️  MISSING DATA WARNING:")
        for f in missing_data:
            print(f"   - {f}")
        print("   -> Please download these from STRING DB or run your raw_data.py script.")
    else:
        print("✅ Raw data files detected.")

# Run the setup logic
print("--- ⚙️ Running Project Setup ---")
create_structure()
check_data_files()
print("--- Setup Complete ---\n")

# %% [markdown]
# 2. Pipeline Orchestrator
#
# We define a helper function to execute standalone scripts.

# %%
import os
import sys
import subprocess
import platform
from pathlib import Path

def run_script(script_path):
    """
    Executes a Python script using a subprocess to ensure clean execution context.
    """
    script_path = Path(script_path)
    
    if not script_path.exists():
        print(f"❌ FATAL ERROR: Could not find script at '{script_path}'")
        return

    print(f"\n--- 🚀 Starting {script_path.name}...")
    
    # Use the current Python executable (sys.executable) to run the script
    command = [sys.executable, str(script_path)]
    
    try:
        # Execute the script, streamlining output to this notebook
        process = subprocess.run(
            command, 
            check=True,
            stdout=sys.stdout,
            stderr=sys.stderr
        )
        print(f"--- ✅ {script_path.name} finished successfully.")
        
    except subprocess.CalledProcessError as e:
        print(f"\n--- ❌ ERROR: {script_path.name} failed with return code {e.returncode}.")

# %% [markdown]
# 3. Pre-requisites
#
# Checking system pre-requisites before starting heavy processing.

# %%
# Run the prerequisite check
# run_script("pre_req.py")

# %% [markdown]
# 4. Data Import
#
# Importing data into the _raw folder

# %%
# Define path to data import
data_import_script = Path("features") / "data_import.py"

# Run import
run_script(data_import_script)

# %% [markdown]
# 5. Data Preprocessing
#
# Cleaning the dataset and preparing the graph structures.

# %%
# Run preprocessing
#run_script("features/preprocessing.py")

# %% [markdown]
# 6. Clustering Algorithms
# Run the graph clustering algorithms. You can uncomment the specific algorithms you wish to run for this session.
#
# A. Louvain Clustering
# Community detection based on modularity optimization.
#
# B. Markov Clustering

# %%
# Uncomment to run Louvain Clustering
run_script("features/01_run_louvain.py")
# Out:
# --- 🚀 Starting 01_run_louvain.py...
# --- ✅ 01_run_louvain.py finished successfully.

# %% [markdown]
# Overview of clustering Louvain

# %%
import sys
import pandas as pd
# Ensure python finds your modules
sys.path.append('./prot_clust_modules')

# Import the new module
from cluster_overview import (
    get_clustering_summary, 
    generate_cluster_stats_table, 
    get_proteins_in_cluster
)

# Config
PICKLE_FILE = "data/output/louvain_clust_julle.pkl"
OUTPUT_DIR = "data/output"

# %%
# Get high-level facts about the network
df_summary = get_clustering_summary(PICKLE_FILE)
# Out:
# [OVERVIEW] Generating global network summary...
#
# --- Network Summary ---
# <style type="text/css">
# </style>
# <table id="T_b1361">
#   <thead>
#     <tr>
#       <th id="T_b1361_level0_col0" class="col_heading level0 col0" >Total Clusters</th>
#       <th id="T_b1361_level0_col1" class="col_heading level0 col1" >Avg Cluster Size</th>
#       <th id="T_b1361_level0_col2" class="col_heading level0 col2" >Median Cluster Size</th>
#       <th id="T_b1361_level0_col3" class="col_heading level0 col3" >Largest Cluster</th>
#       <th id="T_b1361_level0_col4" class="col_heading level0 col4" >Smallest Cluster</th>
#       <th id="T_b1361_level0_col5" class="col_heading level0 col5" >Modularity Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b1361_row0_col0" class="data row0 col0" >32</td>
#       <td id="T_b1361_row0_col1" class="data row0 col1" >411.340000</td>
#       <td id="T_b1361_row0_col2" class="data row0 col2" >376.500000</td>
#       <td id="T_b1361_row0_col3" class="data row0 col3" >1140</td>
#       <td id="T_b1361_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_b1361_row0_col5" class="data row0 col5" >0.757600</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Generate table for all clusters
df_all_clusters = generate_cluster_stats_table(
    PICKLE_FILE, 
    output_filename="all_cluster_metrics.csv", 
    output_dir=OUTPUT_DIR
)
# Out:
# [OVERVIEW] Calculating statistics for all 35 clusters...
#    ✅ Stats saved to: data/output/all_cluster_metrics.csv
#
# --- Top 20 Largest Clusters ---
# <style type="text/css">
# #T_b372f_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b372f_row1_col1 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_b372f_row2_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_b372f_row3_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_b372f_row4_col1, #T_b372f_row5_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_b372f_row6_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_b372f_row7_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_b372f_row8_col1 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_b372f_row9_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_b372f_row10_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_b372f_row11_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b372f_row12_col1 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_b372f_row13_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_b372f_row14_col1 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_b372f_row15_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_b372f_row16_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_b372f_row17_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_b372f_row18_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_b372f_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_b372f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b372f_level0_col0" class="col_heading level0 col0" >Cluster ID</th>
#       <th id="T_b372f_level0_col1" class="col_heading level0 col1" >Size (Nodes)</th>
#       <th id="T_b372f_level0_col2" class="col_heading level0 col2" >Edges</th>
#       <th id="T_b372f_level0_col3" class="col_heading level0 col3" >Density</th>
#       <th id="T_b372f_level0_col4" class="col_heading level0 col4" >Avg Clustering</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b372f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b372f_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_b372f_row0_col1" class="data row0 col1" >1140</td>
#       <td id="T_b372f_row0_col2" class="data row0 col2" >10282</td>
#       <td id="T_b372f_row0_col3" class="data row0 col3" >0.0158</td>
#       <td id="T_b372f_row0_col4" class="data row0 col4" >0.4271</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b372f_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_b372f_row1_col1" class="data row1 col1" >901</td>
#       <td id="T_b372f_row1_col2" class="data row1 col2" >5617</td>
#       <td id="T_b372f_row1_col3" class="data row1 col3" >0.0139</td>
#       <td id="T_b372f_row1_col4" class="data row1 col4" >0.3970</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b372f_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_b372f_row2_col1" class="data row2 col1" >688</td>
#       <td id="T_b372f_row2_col2" class="data row2 col2" >4411</td>
#       <td id="T_b372f_row2_col3" class="data row2 col3" >0.0187</td>
#       <td id="T_b372f_row2_col4" class="data row2 col4" >0.4624</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b372f_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_b372f_row3_col1" class="data row3 col1" >678</td>
#       <td id="T_b372f_row3_col2" class="data row3 col2" >9266</td>
#       <td id="T_b372f_row3_col3" class="data row3 col3" >0.0404</td>
#       <td id="T_b372f_row3_col4" class="data row3 col4" >0.5548</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b372f_row4_col0" class="data row4 col0" >20</td>
#       <td id="T_b372f_row4_col1" class="data row4 col1" >654</td>
#       <td id="T_b372f_row4_col2" class="data row4 col2" >4997</td>
#       <td id="T_b372f_row4_col3" class="data row4 col3" >0.0234</td>
#       <td id="T_b372f_row4_col4" class="data row4 col4" >0.4143</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b372f_row5_col0" class="data row5 col0" >22</td>
#       <td id="T_b372f_row5_col1" class="data row5 col1" >652</td>
#       <td id="T_b372f_row5_col2" class="data row5 col2" >6936</td>
#       <td id="T_b372f_row5_col3" class="data row5 col3" >0.0327</td>
#       <td id="T_b372f_row5_col4" class="data row5 col4" >0.4954</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b372f_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_b372f_row6_col1" class="data row6 col1" >609</td>
#       <td id="T_b372f_row6_col2" class="data row6 col2" >3502</td>
#       <td id="T_b372f_row6_col3" class="data row6 col3" >0.0189</td>
#       <td id="T_b372f_row6_col4" class="data row6 col4" >0.4532</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b372f_row7_col0" class="data row7 col0" >29</td>
#       <td id="T_b372f_row7_col1" class="data row7 col1" >596</td>
#       <td id="T_b372f_row7_col2" class="data row7 col2" >3868</td>
#       <td id="T_b372f_row7_col3" class="data row7 col3" >0.0218</td>
#       <td id="T_b372f_row7_col4" class="data row7 col4" >0.5252</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b372f_row8_col0" class="data row8 col0" >24</td>
#       <td id="T_b372f_row8_col1" class="data row8 col1" >558</td>
#       <td id="T_b372f_row8_col2" class="data row8 col2" >5873</td>
#       <td id="T_b372f_row8_col3" class="data row8 col3" >0.0378</td>
#       <td id="T_b372f_row8_col4" class="data row8 col4" >0.4708</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b372f_row9_col0" class="data row9 col0" >27</td>
#       <td id="T_b372f_row9_col1" class="data row9 col1" >539</td>
#       <td id="T_b372f_row9_col2" class="data row9 col2" >3701</td>
#       <td id="T_b372f_row9_col3" class="data row9 col3" >0.0255</td>
#       <td id="T_b372f_row9_col4" class="data row9 col4" >0.4738</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b372f_row10_col0" class="data row10 col0" >8</td>
#       <td id="T_b372f_row10_col1" class="data row10 col1" >536</td>
#       <td id="T_b372f_row10_col2" class="data row10 col2" >2649</td>
#       <td id="T_b372f_row10_col3" class="data row10 col3" >0.0185</td>
#       <td id="T_b372f_row10_col4" class="data row10 col4" >0.4046</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b372f_row11_col0" class="data row11 col0" >5</td>
#       <td id="T_b372f_row11_col1" class="data row11 col1" >502</td>
#       <td id="T_b372f_row11_col2" class="data row11 col2" >6354</td>
#       <td id="T_b372f_row11_col3" class="data row11 col3" >0.0505</td>
#       <td id="T_b372f_row11_col4" class="data row11 col4" >0.5666</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b372f_row12_col0" class="data row12 col0" >6</td>
#       <td id="T_b372f_row12_col1" class="data row12 col1" >463</td>
#       <td id="T_b372f_row12_col2" class="data row12 col2" >2189</td>
#       <td id="T_b372f_row12_col3" class="data row12 col3" >0.0205</td>
#       <td id="T_b372f_row12_col4" class="data row12 col4" >0.4652</td>
#     </tr>
#     <tr>
#       <th id="T_b372f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b372f_row13_col0" class="data row13 col0" >7</td>
#       <td id="T_b372f_row13_col1" class="data row13 col1" >454</td>
#       <td id="T_b372f_row13_col2" class="data row13 col2" >1652</td>
#       <td id="T_b372f_row13_col3" class="data row13 col3" >0.0161</td>
#       <td id="T_b372f_row13_col4" class="data row13 col4" >0.4053</td>
#     </tr>
#     <tr

# %%
# Select a cluster ID you are interested in (e.g., based on the table above)
INTERESTING_CLUSTER_ID = 23

# Extract list
protein_list = get_proteins_in_cluster(
    PICKLE_FILE, 
    cluster_id=INTERESTING_CLUSTER_ID, 
    output_filename=f"proteins_in_cluster_{INTERESTING_CLUSTER_ID}.txt",
    output_dir=OUTPUT_DIR
)
# Out:
# [OVERVIEW] Fetching proteins for Cluster ID 23...
#    ✅ Saved list to: data/output/proteins_in_cluster_23.txt
#
# --- Proteins in Cluster 23 (Showing top 50 of 354) ---
# ABHD16A, ADRM1, AGTRAP, AHSA1, AKIRIN2, ALX3, AMFR, ANKRD45, ANKZF1, ARHGEF15, ART3, ASPSCR1, ATXN3, AUP1, BAG1, BAG2, BAG3, BAG5, BAG6, BTBD9, C15orf40, CAAP1, CALR3, CALU, CAMLG, CCDC74B, CCDC92, CCT6B, CCT8L2, CDC37, CDC37L1, CDC42BPB, CDC42EP2, CDC42EP3, CDC42EP4, CDC42EP5, CHORDC1, CLPB, CRELD2, DDI1, DERL1, DERL2, DERL3, DESI1, DGCR2, DGCR6, DGCR6L, DNAH10, DNAJA1, DNAJA2
# ... and 304 more.

# %% [markdown]
# Running reproducibillity script - only run if of interest

# %%
# Uncomment to run analyze clusterers
run_script("features/03_reproducibility.py")

# View results
from IPython.display import Image, display
import os

# Define the path where the script saved the image
image_path = "data/output/images/reproducibility_plot.png"

# Check if file exists to avoid errors
if os.path.exists(image_path):
    print("reproducibility_plot.png")
    display(Image(filename=image_path))
else:
    print(f"❌ Image not found at {image_path}. Did the script run successfully?")
# Out:
# --- 🚀 Starting 03_reproducibility.py...
# --- ✅ 03_reproducibility.py finished successfully.
# reproducibility_plot.png

# %% [markdown]
# Running Target bottlenecks

# %%
import sys
# Ensure Python can find your module folder
sys.path.append('./features/prot_clust_modules')

# Import the specific function
from bottleneck_analysis import btl_anal

# Import display tools
from IPython.display import display, IFrame, Image

# --- USER INPUT ---
TARGET = "AGTRAP" 
PICKLE_FILE = "data/output/louvain_clust_julle.pkl"
OUTPUT_DIR = "data/output"
# ------------------

# Call the function
result = btl_anal(TARGET, PICKLE_FILE, OUTPUT_DIR)

# Check results
if result["error"]:
    print(f"❌ {result['error']}")
else:
    print(f"\n✅ Results for Cluster {result['cluster_id']}:")
    
    # 1. Show Top 10 Dataframe
    display(result["dataframe"].head(10))
    
    # 2. Show Static Image
    print("\n--- Static Visualization ---")
    display(Image(filename=result["png_path"]))
    
    # 3. Show Interactive HTML
    if result["html_path"]:
        print("\n--- Interactive Visualization (Scroll/Zoom) ---")
        display(IFrame(src=result["html_path"], width='100%', height='800px'))
# Out:
# --- 🔍 Analyzing Target: AGTRAP ---
# [INFO] Found in Cluster #23 (Size: 354 nodes)
# [INFO] Calculating network metrics (Degree, Betweenness, Clustering)...
#    > Metrics computed in 1.37s
# [INFO] Generating static PNG...
# [SUCCESS] Analysis finished for AGTRAP.
#
# ✅ Results for Cluster 23:
#    Protein  Total_Score        BC  Degree  Clustering
# 0     UFD1           69  0.170020      40    0.189463
# 1  DNAJB11           94  0.094386      31    0.208271
# 2     ZUP1          104  0.049165      24    0.103424
# 3     AMFR          116  0.056762      33    0.277819
# 4   HSPA1L          117  0.044282      30    0.240021
# 5   HSPA1A          121  0.032648      33    0.247955
# 6    STIP1          124  0.032602      36    0.263949
# 7    PDIA3          131  0.051193      19    0.220921
# 8    UBXN7          133  0.043740      28    0.255779
# 9   DNAJB1          137  0.015661      40    0.228813
# --- Static Visualization ---

# %% [markdown]
# B. Markov Clustering (MCL)
#
# Flow simulation based clustering.
#
# Note:
#
# Instead of running the MCL on your computer, just grap the mcl_data.pkl and put it in the "data/output" directory, file here: https://drive.google.com/drive/folders/1lYrvIDpD_2BXirGHBIgoYeByp1yPRsZ4?usp=sharing

# %%
# Uncomment to run High Performance MCL
#run_script("features/05_markov_clust_highperformance_object_out.py")
# Out:
# ❌ FATAL ERROR: Could not find script at 'features/markov_clust_highperformance_object_out.py'

# %%
import sys
import pandas as pd
# Ensure python finds your modules
sys.path.append('features/prot_clust_modules')

# Import the new module
from cluster_overview import (
    get_clustering_summary, 
    generate_cluster_stats_table, 
    get_proteins_in_cluster
)

# Config
PICKLE_FILE = "data/output/mcl_data.pkl"
OUTPUT_DIR = "data/output"

# %% [markdown]
# Overview of Markov Clustering

# %%
# Get high-level facts about the network
df_summary = get_clustering_summary(PICKLE_FILE)
# Out:
# [OVERVIEW] Generating global network summary...
#
# --- Network Summary ---
# <style type="text/css">
# </style>
# <table id="T_5d678">
#   <thead>
#     <tr>
#       <th id="T_5d678_level0_col0" class="col_heading level0 col0" >Total Clusters</th>
#       <th id="T_5d678_level0_col1" class="col_heading level0 col1" >Avg Cluster Size</th>
#       <th id="T_5d678_level0_col2" class="col_heading level0 col2" >Median Cluster Size</th>
#       <th id="T_5d678_level0_col3" class="col_heading level0 col3" >Largest Cluster</th>
#       <th id="T_5d678_level0_col4" class="col_heading level0 col4" >Smallest Cluster</th>
#       <th id="T_5d678_level0_col5" class="col_heading level0 col5" >Modularity Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5d678_row0_col0" class="data row0 col0" >1564</td>
#       <td id="T_5d678_row0_col1" class="data row0 col1" >8.420000</td>
#       <td id="T_5d678_row0_col2" class="data row0 col2" >4.000000</td>
#       <td id="T_5d678_row0_col3" class="data row0 col3" >171</td>
#       <td id="T_5d678_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_5d678_row0_col5" class="data row0 col5" >0.557600</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Generate table for all clusters
df_all_clusters = generate_cluster_stats_table(
    PICKLE_FILE, 
    output_filename="all_cluster_metrics.csv", 
    output_dir=OUTPUT_DIR
)
# Out:
# [OVERVIEW] Calculating statistics for all clusters...
#    ✅ Stats saved to: data/output/all_cluster_metrics.csv
#
# --- Top 20 Largest Clusters ---
# <style type="text/css">
# #T_41966_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_41966_row1_col1 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_41966_row2_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_41966_row3_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_41966_row4_col1 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_41966_row5_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_41966_row6_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_41966_row7_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_41966_row8_col1 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_41966_row9_col1, #T_41966_row10_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_41966_row11_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_41966_row12_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_41966_row13_col1, #T_41966_row14_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_41966_row15_col1, #T_41966_row16_col1, #T_41966_row17_col1, #T_41966_row18_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_41966_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_41966">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41966_level0_col0" class="col_heading level0 col0" >Cluster ID</th>
#       <th id="T_41966_level0_col1" class="col_heading level0 col1" >Size (Nodes)</th>
#       <th id="T_41966_level0_col2" class="col_heading level0 col2" >Edges</th>
#       <th id="T_41966_level0_col3" class="col_heading level0 col3" >Density</th>
#       <th id="T_41966_level0_col4" class="col_heading level0 col4" >Avg Clustering</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41966_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41966_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_41966_row0_col1" class="data row0 col1" >171</td>
#       <td id="T_41966_row0_col2" class="data row0 col2" >3462</td>
#       <td id="T_41966_row0_col3" class="data row0 col3" >0.2382</td>
#       <td id="T_41966_row0_col4" class="data row0 col4" >0.6766</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41966_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_41966_row1_col1" class="data row1 col1" >165</td>
#       <td id="T_41966_row1_col2" class="data row1 col2" >2745</td>
#       <td id="T_41966_row1_col3" class="data row1 col3" >0.2029</td>
#       <td id="T_41966_row1_col4" class="data row1 col4" >0.5306</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41966_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_41966_row2_col1" class="data row2 col1" >135</td>
#       <td id="T_41966_row2_col2" class="data row2 col2" >1759</td>
#       <td id="T_41966_row2_col3" class="data row2 col3" >0.1945</td>
#       <td id="T_41966_row2_col4" class="data row2 col4" >0.5146</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_41966_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_41966_row3_col1" class="data row3 col1" >127</td>
#       <td id="T_41966_row3_col2" class="data row3 col2" >3533</td>
#       <td id="T_41966_row3_col3" class="data row3 col3" >0.4416</td>
#       <td id="T_41966_row3_col4" class="data row3 col4" >0.7249</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_41966_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_41966_row4_col1" class="data row4 col1" >118</td>
#       <td id="T_41966_row4_col2" class="data row4 col2" >2299</td>
#       <td id="T_41966_row4_col3" class="data row4 col3" >0.3330</td>
#       <td id="T_41966_row4_col4" class="data row4 col4" >0.7717</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_41966_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_41966_row5_col1" class="data row5 col1" >117</td>
#       <td id="T_41966_row5_col2" class="data row5 col2" >713</td>
#       <td id="T_41966_row5_col3" class="data row5 col3" >0.1051</td>
#       <td id="T_41966_row5_col4" class="data row5 col4" >0.4773</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_41966_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_41966_row6_col1" class="data row6 col1" >112</td>
#       <td id="T_41966_row6_col2" class="data row6 col2" >2708</td>
#       <td id="T_41966_row6_col3" class="data row6 col3" >0.4356</td>
#       <td id="T_41966_row6_col4" class="data row6 col4" >0.6276</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_41966_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_41966_row7_col1" class="data row7 col1" >92</td>
#       <td id="T_41966_row7_col2" class="data row7 col2" >966</td>
#       <td id="T_41966_row7_col3" class="data row7 col3" >0.2308</td>
#       <td id="T_41966_row7_col4" class="data row7 col4" >0.7510</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_41966_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_41966_row8_col1" class="data row8 col1" >83</td>
#       <td id="T_41966_row8_col2" class="data row8 col2" >2029</td>
#       <td id="T_41966_row8_col3" class="data row8 col3" >0.5962</td>
#       <td id="T_41966_row8_col4" class="data row8 col4" >0.7694</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_41966_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_41966_row9_col1" class="data row9 col1" >81</td>
#       <td id="T_41966_row9_col2" class="data row9 col2" >825</td>
#       <td id="T_41966_row9_col3" class="data row9 col3" >0.2546</td>
#       <td id="T_41966_row9_col4" class="data row9 col4" >0.4451</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_41966_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_41966_row10_col1" class="data row10 col1" >81</td>
#       <td id="T_41966_row10_col2" class="data row10 col2" >840</td>
#       <td id="T_41966_row10_col3" class="data row10 col3" >0.2593</td>
#       <td id="T_41966_row10_col4" class="data row10 col4" >0.5735</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_41966_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_41966_row11_col1" class="data row11 col1" >80</td>
#       <td id="T_41966_row11_col2" class="data row11 col2" >1098</td>
#       <td id="T_41966_row11_col3" class="data row11 col3" >0.3475</td>
#       <td id="T_41966_row11_col4" class="data row11 col4" >0.6325</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_41966_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_41966_row12_col1" class="data row12 col1" >76</td>
#       <td id="T_41966_row12_col2" class="data row12 col2" >1000</td>
#       <td id="T_41966_row12_col3" class="data row12 col3" >0.3509</td>
#       <td id="T_41966_row12_col4" class="data row12 col4" >0.6749</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_41966_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_41966_row13_col1" class="data row13 col1" >72</td>
#       <td id="T_41966_row13_col2" class="data row13 col2" >790</td>
#       <td id="T_41966_row13_col3" class="data row13 col3" >0.3091</td>
#       <td id="T_41966_row13_col4" class="data row13 col4" >0.5969</td>
#     </tr>
#     <tr>
#       <th id="T_41966_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_41966_row14_col0" class="data row14 col0" >13</td>
#       <td id="T_41966_row14_col1" class="data row14 col1" >72</td>

# %%
# Select a cluster ID you are interested in (e.g., based on the table above)
INTERESTING_CLUSTER_ID = 23

# Extract list
protein_list = get_proteins_in_cluster(
    PICKLE_FILE, 
    cluster_id=INTERESTING_CLUSTER_ID, 
    output_filename=f"proteins_in_cluster_{INTERESTING_CLUSTER_ID}.txt",
    output_dir=OUTPUT_DIR
)
# Out:
# [OVERVIEW] Fetching proteins for Cluster ID 23...
#    ✅ Saved list to: data/output/proteins_in_cluster_23.txt
#
# --- Proteins in Cluster 23 (Showing top 50 of 55) ---
# ACKR2, ACKR3, ACKR4, CCL1, CCL11, CCL13, CCL14, CCL15, CCL16, CCL17, CCL18, CCL19, CCL20, CCL21, CCL22, CCL23, CCL24, CCL25, CCL26, CCL27, CCL28, CCL3L1, CCL4L2, CCL7, CCL8, CCR1, CCR10, CCR3, CCR4, CCR6, CCR8, CCR9, CCRL2, CX3CL1, CX3CR1, CXCL11, CXCL13, CXCL14, CXCL16, CXCL17, CXCL2, CXCL3, CXCL5, CXCL6, CXCR1, CXCR2, CXCR3, CXCR5, CXCR6, PF4
# ... and 5 more.

# %% [markdown]
# Running Target bottlenecks

# %%
import sys
# Ensure Python can find your module folder
sys.path.append('./features/prot_clust_modules')

# Import the specific function
from bottleneck_analysis import btl_anal

# Import display tools
from IPython.display import display, IFrame, Image

# --- USER INPUT ---
target_protein = "CCL1" 
pickle_file = PICKLE_FILE
output_dir = OUTPUT_DIR
# ------------------

# Call the function
result = btl_anal(target_protein, pickle_file, output_dir)

# Check results
if result["error"]:
    print(f"❌ {result['error']}")
else:
    print(f"\n✅ Results for Cluster {result['cluster_id']}:")
    
    # 1. Show Top 10 Dataframe
    display(result["dataframe"].head(10))
    
    # 2. Show Static Image
    print("\n--- Static Visualization ---")
    display(Image(filename=result["png_path"]))
    
    # 3. Show Interactive HTML
    if result["html_path"]:
        print("\n--- Interactive Visualization (Scroll/Zoom) ---")
        display(IFrame(src=result["html_path"], width='100%', height='800px'))
# Out:
# --- 🔍 Analyzing Target: CCL1 ---
# [INFO] Found in Cluster #23 (Size: 55 nodes)
# [INFO] Calculating network metrics (Degree, Betweenness, Clustering)...
#    > Metrics computed in 0.12s
# [INFO] Generating static PNG...
# [SUCCESS] Analysis finished for CCL1.
#
# ✅ Results for Cluster 23:
#   Protein  Total_Score        BC  Degree  Clustering
# 0    CCR3            7  0.037037      48    0.567663
# 1   CCL20           20  0.023760      45    0.577711
# 2   CXCR5           22  0.020964      45    0.581312
# 3   CCL21           26  0.008036      46    0.570143
# 4    CCR9           27  0.017121      41    0.560260
# 5   CCL27           28  0.018169      41    0.574277
# 6   CCR10           28  0.036688      41    0.570600
# 7   CXCR2           32  0.013277      44    0.596858
# 8   CXCR3           32  0.010482      45    0.596579
# 9    XCR1           35  0.047869      31    0.436241
# --- Static Visualization ---

# %%
# !pip install gseapy
# Out:
# Collecting gseapy
#   Using cached gseapy-1.1.11.tar.gz (116 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy>=1.13.0 (from gseapy)
#   Downloading numpy-2.3.5-cp311-cp311-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting scipy (from gseapy)
#   Downloading scipy-1.16.3-cp311-cp311-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting pandas (from gseapy)
#   Downloading pandas-2.3.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (91 kB)
# Collecting matplotlib>=2.2 (from gseapy)
#   Downloading matplotlib-3.10.7-cp311-cp311-macosx_10_12_x86_64.whl.metadata (11 kB)
# Collecting requests (from gseapy)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=2.2->gseapy)
#   Downloading contourpy-1.3.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=2.2->gseapy)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=2.2->gseapy)
#   Downloading fonttools-4.60.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=2.2->gseapy)
#   Downloading kiwisolver-1.4.9-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.3 kB)
# Collecting packaging>=20.0 (from matplotlib>=2.2->gseapy)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow>=8 (from matplotlib>=2.2->gseapy)
#   Downloading pillow-12.0.0-cp311-cp311-macosx_10_10_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib>=2.2->gseapy)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=2.2->gseapy)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib>=2.2->gseapy)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting pytz>=2020.1 (from pandas->gseapy)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->gseapy)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests->gseapy)
#   Downloading charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->gseapy)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->gseapy)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->gseapy)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Downloading matplotlib-3.10.7-cp311-cp311-macosx_10_12_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 28.3 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp311-cp311-macosx_10_9_x86_64.whl (288 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp311-cp311-macosx_10_9_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 30.9 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-macosx_10_9_x86_64.whl (66 kB)
# Downloading numpy-2.3.5-cp311-cp311-macosx_14_0_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 39.5 MB/s  0:00:00
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pillow-12.0.0-cp311-cp311-macosx_10_10_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 36.8 MB/s  0:00:00
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading pandas-2.3.3-cp311-cp311-macosx_10_9_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 39.1 MB/s  0:00:00 eta 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl (206 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading scipy-1.16.3-cp311-cp311-macosx_14_0_x86_64.whl (23.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 53.7 MB/s  0:00:00m0:00:0100:01
# Building wheels for collected packages: gseapy
#   Building wheel for gseapy (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for gseapy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [60 lines of output]
#       <string>:10: SetuptoolsDeprecationWarning: The test command is disabled and references to it are deprecated.
#       !!
#
#               ********************************************************************************
#               Please remove any references to `setuptools.command.test` in all supported versions of the affected package.
#
#               This deprecation is overdue, please update your project and remove deprecated
#               calls to avoid build errors in the future.
#               ********************************************************************************
#
#       !!
#       /private/var/folders/j9/kr1ffhgx3d3ghvw6pmtt4msh0000gn/T/pip-build-env-gms1fx0b/overlay/lib/python3.11/site-packages/setuptools/_distutils/dist.py:289: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       /private/var/folders/j9/kr1ffhgx3d3ghvw6pmtt4msh0000gn/T/pip-build-env-gms1fx0b/overlay/lib/python3.11/site-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/algorithm.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/ssgsea.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/plot.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/enrichr.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/msigdb.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/__init__.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/parser.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/scipalette.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/utils.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/stats.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/gsva.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/__main__.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/base.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/gsea.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       copying gseapy/biomart.py -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy
#       creating build/lib.macosx-10.15-x86_64-cpython-311/gseapy/data
#       copying gseapy/data/palette.json -> build/lib.macosx-10.15-x86_64-cpython-311/gseapy/data
#       running build_ext
#       running build_rust
#       error: can't find Rust compiler
#
#       If you are using an outdated pip version, it is possible a prebuilt wheel is available for this package but pip is not able to install from it. Installing from the wheel would avoid the need for a Rust compiler.
#
#       To update pip, run:
#
#           pip install --upgrade pip
#
#       and then retry package installation.
#
#       If you did intend to build this package from source, try installing a Rust compiler from your system package manager and ensure it is on the PATH during installation. Alternatively, rustup (available at https://rustup.rs) is the recommended way to download and update the Rust compiler toolchain.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gseapy
# Failed to build gseapy
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> gseapy

# %% [markdown]
# 7. Analysis & Visualization
# Analyze the results of the clustering and generate plots.

# %%
# Run analysis for Louvain results
run_script("features/analyze_results_louvain.py")

# %%
print("\n✨ All pipeline tasks complete! ✨")
